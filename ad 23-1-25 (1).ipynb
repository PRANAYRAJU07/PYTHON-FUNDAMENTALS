# %%
import matplotlib.pyplot as plt 
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\prana\Downloads\climate_change.csv")
df
# Out:
#      Year  Month    MEI     CO2      CH4      N2O   CFC-11   CFC-12  \
# 0    1983      5  2.556  345.96  1638.59  303.677  191.324  350.113
# 1    1983      6  2.167  345.52  1633.71  303.746  192.057  351.848
# 2    1983      7  1.741  344.15  1633.22  303.795  192.818  353.725
# 3    1983      8  1.130  342.25  1631.35  303.839  193.602  355.633
# 4    1983      9  0.428  340.17  1648.40  303.901  194.392  357.465
# ..    ...    ...    ...     ...      ...      ...      ...      ...
# 303  2008      8 -0.266  384.15  1779.88  321.405  244.200  535.072
# 304  2008      9 -0.643  383.09  1795.08  321.529  244.083  535.048
# 305  2008     10 -0.780  382.99  1814.18  321.796  244.080  534.927
# 306  2008     11 -0.621  384.13  1812.37  322.013  244.225  534.906
# 307  2008     12 -0.666  385.56  1812.88  322.182  244.204  535.005
#
#            TSI  Aerosols   Temp
# 0    1366.1024    0.0863  0.109
# 1    1366.1208    0.0794  0.118
# 2    1366.2850    0.0731  0.137
# ...

# %%
df1=sns.load_dataset('taxis')
df1
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
sns.barplot(x='payment',y='total',data=df1,color='red',estimator='mean')
plt.show()
plt.tight_layout()

# %%
sns.barplot(x='payment',y='total',data=df1,color='red',estimator='sum')
plt.show()
plt.tight_layout()

# %%
sns.barplot(x='payment',y='total',data=df1,color='red',estimator='std')
plt.show()
plt.tight_layout()

# %%
sns.histplot(x=df1['fare'],color='blue')
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(x=df1['fare'],palette=['blue','red'],hue=df1['payment'])
plt.show()

# %%
sns.boxplot(x=df1['fare'],color='skyblue')
# Out:
# <Axes: xlabel='fare'>

# %%
sns.boxplot(x=df1['total'],color='skyblue')
# Out:
# <Axes: xlabel='total'>

# %%
iris_data=sns.load_dataset('iris')
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.boxplot(x=iris_data['sepal_length'],color='indigo')
# Out:
# <Axes: xlabel='sepal_length'>

# %%
#lower_limit=q1-1.5(q3-q1)
#upper_limit=q3+1.5(q3-q1)

# %%
sns.scatterplot(x=df1['fare'],y=df1['total'],palette=['blue','red'],hue=df1['payment'])
plt.show()

# %%
sns.distplot(x=df1['fare'],hist=False,kde=True)
plt.show()

# %%
sns.distplot(x=df1['fare'],hist=True,kde=True)
plt.show()

# %%
sns.stripplot(x=df1['fare'],y=df1['color'],palette=['blue','red'])
plt.show()

# %%
sns.stripplot(x=df1['fare'],y=df1['total'],palette=['blue','red'],hue=df1['payment'])
plt.show()

# %%
sns.swarmplot(x=df1['fare'],y=df1['total'],palette=['blue','red'],hue=df1['payment'])
plt.show()

# %%
sns.lineplot(x=df1['fare'],y=df1['total'])
plt.show()

# %%
sns.lineplot(x=df1['fare'],y=df1['total'],palette=['blue','red'],hue=df1['payment'])
plt.show()

# %%
sns.countplot(x=df1['payment'])
# Out:
# <Axes: xlabel='payment', ylabel='count'>

# %%
df1['payment'].value_counts()
# Out:
# credit card    4577
# cash           1812
# Name: payment, dtype: int64
